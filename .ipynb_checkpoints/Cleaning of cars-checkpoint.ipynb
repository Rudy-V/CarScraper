# %%
import pandas as pd

# %%
df = pd.read_csv('cars.csv')
df.columns = ['Random number', "Total price", "Montly installment", "Year.Car.Model", "Used.Transmission","Seller Name", "Seller location", "Km from you"]
df.drop(df.columns[[0, 7]], axis=1, inplace=True)

# %%
df.head()
# Out:
#   Total price Montly installment                       Year.Car.Model  \
# 0    R 99 999        R 1 981 p/m    2013 Honda Brio Hatch 1.2 Comfort
# 1    R 99 999        R 1 981 p/m           2015 Suzuki Celerio 1.0 GL
# 2    R 99 995        R 1 981 p/m          2014 Ford Figo 1.4 Ambiente
# 3    R 99 950        R 1 980 p/m  2012 Mazda Mazda3 Sedan 1.6 Dynamic
# 4    R 99 950        R 1 980 p/m             2012 Hyundai i10 1.1 GLS
#
#           Used.Transmission                   Seller Name  \
# 0  Used Car131 000 kmManual            CITTON CARS MENLYN
# 1  Used Car105 000 kmManual            CITTON CARS GEZINA
# 2  Used Car177 000 kmManual            INSPECTACAR GEZINA
# 3  Used Car203 039 kmManual  AUTO VIEW PRE OWNED BOKSBURG
# 4  Used Car157 612 kmManual                  SA MOTORCORP
#
#           Seller location
# 0        Menlyn, Pretoria
# 1        Gezina, Pretoria
# 2  Capital Park, Pretoria
# 3    Ravenswood, Boksburg
# 4      Bordeaux, Randburg

# %%
Year = []
Car_brand = []
Car_model = []
Car_mis = []
for row in df["Year.Car.Model"]:
    temp = row.split()
    Year.append(temp[0])
    Car_brand.append(temp[1])
    Car_model.append(temp[2])
    Car_mis.append(temp[3:])

# %%
df['year'] = Year
df['manufacturer'] = Car_brand
df['model'] = Car_model
df['extra'] = Car_mis

# %%
df
# Out:
#     Total price Montly installment                       Year.Car.Model  \
# 0      R 99 999          1 981 p/m    2013 Honda Brio Hatch 1.2 Comfort
# 1      R 99 999          1 981 p/m           2015 Suzuki Celerio 1.0 GL
# 2      R 99 995          1 981 p/m          2014 Ford Figo 1.4 Ambiente
# 3      R 99 950          1 980 p/m  2012 Mazda Mazda3 Sedan 1.6 Dynamic
# 4      R 99 950          1 980 p/m             2012 Hyundai i10 1.1 GLS
# ..          ...                ...                                  ...
# 755    R 65 000          1 288 p/m        2014 Peugeot 3008 1.6T Active
# 756    R 65 000          1 288 p/m          2014 Kia Soul 1.6 High-Spec
# 757    R 65 000          1 288 p/m      2013 Chevrolet Aveo Hatch 1.6 L
# 758    R 64 999          1 288 p/m             2015 Ford Figo 1.4 Trend
# 759    R 64 950          1 287 p/m    2013 Toyota Aygo 3-Door 1.0 Fresh
#
#             Used.Transmission                   Seller Name  \
# 0    Used Car131 000 kmManual            CITTON CARS MENLYN
# 1    Used Car105 000 kmManual            CITTON CARS GEZINA
# 2    Used Car177 000 kmManual            INSPECTACAR GEZINA
# 3    Used Car203 039 kmManual  AUTO VIEW PRE OWNED BOKSBURG
# 4    Used Car157 612 kmManual                  SA MOTORCORP
# ..                        ...                           ...
# 755  Used Car104 500 kmManual                     GI MOTORS
# 756   Used Car87 000 kmManual                   TONY MOTORS
# 757   Used Car77 000 kmManual          STEPHENS AUTO MOTORS
# 758  Used Car147 000 kmManual                SMART CARS JHB
# 759  Used Car189 000 kmManual        INFINITI AUTO BOKSBURG
#
#                         Seller location  year manufacturer    model  \
# 0                      Menlyn, Pretoria  2013        Honda     Brio
# 1                      Gezina, Pretoria  2015       Suzuki  Celerio
# 2                Capital Park, Pretoria  2014         Ford     Figo
# 3                  Ravenswood, Boksburg  2012        Mazda   Mazda3
# 4                    Bordeaux, Randburg  2012      Hyundai      i10
# ..                                  ...   ...          ...      ...
# 755          Pretoria Central, Pretoria  2014      Peugeot     3008
# 756           Rhodesfield, Kempton Park  2014          Kia     Soul
# 757  Kempton Park Central, Kempton Park  2013    Chevrolet     Aveo
# 758   Bezuidenhout Valley, Johannesburg  2015         Ford     Figo
# 759                   Bardene, Boksburg  2013       Toyota     Aygo
#
#                      extra
# 0    [Hatch, 1.2, Comfort]
# 1                [1.0, GL]
# 2          [1.4, Ambiente]
# 3    [Sedan, 1.6, Dynamic]
# 4               [1.1, GLS]
# ..                     ...
# 755         [1.6T, Active]
# 756       [1.6, High-Spec]
# 757        [Hatch, 1.6, L]
# 758           [1.4, Trend]
# 759   [3-Door, 1.0, Fresh]
#
# [760 rows x 10 columns]

# %%
df['Montly installment'] = df['Montly installment'].str.replace("R","")
df['Montly installment'] = df['Montly installment'].str.replace("p/m","")
df['Montly installment'] = df['Montly installment'].str.replace(" ","")
df['Montly installment'] = df['Montly installment'].str.strip()
df['Montly installment'] = df['Montly installment'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [25], line 4
#       2 df['Montly installment'] = df['Montly installment'].str.replace("p/m","")
#       3 df['Montly installment'] = df['Montly installment'].str.strip()
# ----> 4 df['Montly installment'] = df['Montly installment'].astype(int)
#
# File c:\users\rudol\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File c:\users\rudol\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\managers.py:450, in BaseBlockManager.astype(self, dtype, copy, errors)
#     449 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 450     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File c:\users\rudol\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File c:\users\rudol\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File c:\users\rudol\appdata\local\programs\python\python38\lib\site-packages\pandas\core\dtypes\astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File c:\users\rudol\appdata\local\programs\python\python38\lib\site-packages\pandas\core\dtypes\astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\users\rudol\appdata\local\programs\python\python38\lib\site-packages\pandas\core\dtypes\astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '1 981'

# %%
type(df['Montly installment'][0])
